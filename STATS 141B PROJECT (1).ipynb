# %% [markdown]
# # LAYOUT OF PROJECT
#
# ## Q: How have the characteristics of Billboard Hot 100 songs changed between 2020 and 2025 using Spotify track data?
#
# ## Are songs getting shorter?
#
# ## Are songs becoming more explicit?
#
# ## Are collaborations increasing?

# %%
#packages
import pandas as pd
import requests
import time
import spotipy
import re
import seaborn as sns
import matplotlib.pyplot as plt
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# wiki links to the billboard top 100 for years 2020 & 2025

wiki2020_url = "https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2020"
wiki2025_url = "https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2025"

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:145.0) Gecko/20100101 Firefox/145.0'
}

# function to scrape the main billboard table from wikipedia
def get_billboard_table(url, year):

    response = requests.get(url, headers=headers)
    response.raise_for_status()

    tables = pd.read_html(response.text)

    # first table contains the song data
    df = tables[0]  
    
    # rename columns
    df = df.rename(columns={
        "No.": "rank",
        "Title": "song",
        "Artist(s)": "artist"
    })
    # remove quotation marks from song titles
    df["song"] = df["song"].str.replace('"', '')
    df["year"] = year

    return df

# %%
df2020 = get_billboard_table(wiki2020_url, 2020)
df2025 = get_billboard_table(wiki2025_url, 2025)

# %%
df2020.head(10)
# Out:
#    rank               song                        artist  year
# 0     1    Blinding Lights                    The Weeknd  2020
# 1     2            Circles                   Post Malone  2020
# 2     3            The Box                   Roddy Ricch  2020
# 3     4    Don't Start Now                      Dua Lipa  2020
# 4     5           Rockstar  DaBaby featuring Roddy Ricch  2020
# 5     6          Adore You                  Harry Styles  2020
# 6     7       Life Is Good        Future featuring Drake  2020
# 7     8           Memories                      Maroon 5  2020
# 8     9          The Bones                  Maren Morris  2020
# 9    10  Someone You Loved                 Lewis Capaldi  2020

# %%
df2025.head(10)
# Out:
#    rank                song                               artist  year
# 0     1    Die with a Smile             Lady Gaga and Bruno Mars  2025
# 1     2              Luther               Kendrick Lamar and SZA  2025
# 2     3  A Bar Song (Tipsy)                            Shaboozey  2025
# 3     4        Lose Control                          Teddy Swims  2025
# 4     5  Birds of a Feather                        Billie Eilish  2025
# 5     6    Beautiful Things                         Benson Boone  2025
# 6     7            Ordinary                          Alex Warren  2025
# 7     8     I Had Some Help  Post Malone featuring Morgan Wallen  2025
# 8     9                APT.                  Rosé and Bruno Mars  2025
# 9    10      Pink Pony Club                        Chappell Roan  2025

# %%
# combine both datasets into one dataframe
allsongs = pd.concat([df2020, df2025], ignore_index=True)

allsongs
# Out:
#      rank             song                        artist  year
# 0       1  Blinding Lights                    The Weeknd  2020
# 1       2          Circles                   Post Malone  2020
# 2       3          The Box                   Roddy Ricch  2020
# 3       4  Don't Start Now                      Dua Lipa  2020
# 4       5         Rockstar  DaBaby featuring Roddy Ricch  2020
# ..    ...              ...                           ...   ...
# 195    96    Dark Thoughts                     Lil Tecca  2025
# 196    97          No Pole                   Don Toliver  2025
# 197    98           Folded                       Kehlani  2025
# 198    99         Superman                 Morgan Wallen  2025
# 199   100             Loco                    Netón Vega  2025
#
# [200 rows x 4 columns]

# %%
#seperate column where we only get the main artist for each song (exclude the collabs)
allsongs["artist_clean"] = allsongs["artist"].str.replace(
    r" featuring.*| and .*|,.*|:.*",
    "",
    regex=True
)

allsongs
# Out:
#      rank             song                        artist  year   artist_clean
# 0       1  Blinding Lights                    The Weeknd  2020     The Weeknd
# 1       2          Circles                   Post Malone  2020    Post Malone
# 2       3          The Box                   Roddy Ricch  2020    Roddy Ricch
# 3       4  Don't Start Now                      Dua Lipa  2020       Dua Lipa
# 4       5         Rockstar  DaBaby featuring Roddy Ricch  2020         DaBaby
# ..    ...              ...                           ...   ...            ...
# 195    96    Dark Thoughts                     Lil Tecca  2025      Lil Tecca
# 196    97          No Pole                   Don Toliver  2025    Don Toliver
# 197    98           Folded                       Kehlani  2025        Kehlani
# 198    99         Superman                 Morgan Wallen  2025  Morgan Wallen
# 199   100             Loco                    Netón Vega  2025     Netón Vega
#
# [200 rows x 5 columns]

# %% [markdown]
# # SPOTIFY API LOOP

# %%
auth = SpotifyClientCredentials(
    client_id="", #id from spotify
    client_secret=""
)

sp = spotipy.Spotify(auth_manager=auth)

# %%
# create lists to store spotify data
durations = []
explicit_flags = []

# loop through every song and search spotify
for i, row in allsongs.iterrows():
    
    # search query uses song title and main artist
    query = f'{row["song"]} {row["artist_clean"]}'.replace('"','')

    result = sp.search(
        q=query,
        type="track",
        limit=1,
        market="US"
    )
        
    # if spotify returns a track, save its data
    if result["tracks"]["items"]:
        track = result["tracks"]["items"][0]

        durations.append(track.get("duration_ms"))
        explicit_flags.append(track.get("explicit"))

    # if nothing is found, we store missing values
    else:
        durations.append(None)
        explicit_flags.append(None)
    
    # avoid the rate limits
    time.sleep(2.5)

allsongs["duration_ms"] = durations
allsongs["explicit"] = explicit_flags

# %%
# save the dataset to csv in case we hit api limits
allsongs.to_csv("spotify_billboard_data.csv", index=False)

# %%
allsongs = pd.read_csv("spotify_billboard_data.csv")

# %%
pd.set_option("display.max_rows", None)
allsongs
# Out:
#      rank                               song  \
# 0       1                    Blinding Lights
# 1       2                            Circles
# 2       3                            The Box
# 3       4                    Don't Start Now
# 4       5                           Rockstar
# 5       6                          Adore You
# 6       7                       Life Is Good
# 7       8                           Memories
# 8       9                          The Bones
# 9      10                  Someone You Loved
# 10     11                             Say So
# 11     12                             I Hope
# 12     13                       Whats Poppin
# 13     14                       Dance Monkey
# 14     15                             Savage
# 15     16                            Roxanne
# 16     17                         Intentions
# 17     18                Everything I Wanted
# 18     19              Roses (Imanbek remix)
# 19     20                   Watermelon Sugar
# 20     21                      Before You Go
# 21     22                            Falling
# 22     23                       10,000 Hours
# 23     24                                WAP
# 24     25                            Ballin'
# 25     26                    Hot Girl Bummer
# 26     27                    Blueberry Faygo
# 27     28                          Heartless
# 28     29                                Bop
# 29     30                Lose You to Love Me
# 30     31                       Good as Hell
# 31     32                       Toosie Slide
# 32     33                     Break My Heart
# 33     34                        Chasin' You
# 34     35   Savage Love (Laxed – Siren Beat)
# 35     36                        No Guidance
# 36     37                           My Oh My
# 37     38                           Dynamite
# 38     39                           Go Crazy
# 39     40                       High Fashion
# 40     41                Laugh Now Cry Later
# 41     42                               Woah
# 42     43                          Death Bed
# 43     44                           Señorita
# 44     45                Highest in the Room
# 45     46                            Bad Guy
# 46     47                               Mood
# 47     48                         Rain on Me
# 48     49                      For the Night
# 49     50          Ritmo (Bad Boys for Life)
# 50     51                       Heart on Ice
# 51     52                     Nobody but You
# 52     53                         Trampoline
# 53     54                          Come & Go
# 54     55                        Truth Hurts
# 55     56            If the World Was Ending
# 56     57                            We Paid
# 57     58                              Yummy
# 58     59                       One Man Band
# 59     60                     Got What I Got
# 60     61                        Sunday Best
# 61     62                           Godzilla
# 62     63                             Bandit
# 63     64                         Party Girl
# 64     65            Die from a Broken Heart
# 65     66                            Popstar
# 66     67    All I Want for Christmas Is You
# 67     68                  One of Them Girls
# 68     69                     Hard to Forget
# 69     70                      One Margarita
# 70     71                             Panini
# 71     72                                Hot
# 72     73            I Hope You're Happy Now
# 73     74                Emotionally Scarred
# 74     75                           Suicidal
# 75     76                 The Bigger Picture
# 76     77                         Only Human
# 77     78                            The Woo
# 78     79                        Sum 2 Prove
# 79     80                       Stuck with U
# 80     81                        Mood Swings
# 81     82                  You Should Be Sad
# 82     83                               Dior
# 83     84                         Supalonely
# 84     85            Even Though I'm Leaving
# 85     86                         The Scotts
# 86     87                              Juicy
# 87     88                       Be Like That
# 88     89                           Homesick
# 89     90                        Rags2Riches
# 90     91                           Bluebird
# 91     92                       Wishing Well
# 92     93                         Does to Me
# 93     94                  Pussy Fairy (OTW)
# 94     95              ILY (I Love You Baby)
# 95     96              More Than My Hometown
# 96     97                      Lovin' on You
# 97     98                           Said Sum
# 98     99                              Slide
# 99    100                       Walk Em Down
# 100     1                   Die with a Smile
# 101     2                             Luther
# 102     3                 A Bar Song (Tipsy)
# 103     4                       Lose Control
# 104     5                 Birds of a Feather
# 105     6                   Beautiful Things
# 106     7                           Ordinary
# 107     8                    I Had Some Help
# 108     9                               APT.
# 109    10                     Pink Pony Club
# 110    11                      Love Somebody
# 111    12                           Espresso
# 112    13                    I'm the Problem
# 113    14                     That's So True
# 114    15                             TV Off
# 115    16                           Timeless
# 116    17                        Not Like Us
# 117    18                       Just in Case
# 118    19                              Taste
# 119    20                        Squabble Up
# 120    21                          30 for 30
# 121    22                               Mutt
# 122    23                          Good News
# 123    24                              Nokia
# 124    25                             Golden
# 125    26                         Wildflower
# 126    27                        What I Want
# 127    28                              Messy
# 128    29                         Stargazing
# 129    30                        Love Me Not
# 130    31                   Good Luck, Babe!
# 131    32                     No One Noticed
# 132    33                        All the Way
# 133    34                          Too Sweet
# 134    35                          Worst Way
# 135    36                        Sailor Song
# 136    37    Sorry I'm Here for Someone Else
# 137    38                           Manchild
# 138    39                            Anxiety
# 139    40                       I Got Better
# 140    41                             Sticky
# 141    42                          Undressed
# 142    43                        I Never Lie
# 143    44                    Back to Friends
# 144    45                           Bed Chem
# 145    46                         Sports Car
# 146    47                   Mystical Magical
# 147    48               Whatchu Kno About Me
# 148    49                             Indigo
# 149    50               Please Please Please
# 150    51                               DTMF
# 151    52                        Blue Strips
# 152    53                           Peekaboo
# 153    54                          Your Idol
# 154    55                          High Road
# 155    56                        Abracadabra
# 156    57                                Who
# 157    58                       Burning Blue
# 158    59    All I Want for Christmas Is You
# 159    60                            Daisies
# 160    61                           Soda Pop
# 8                Maren Morris       197298     False
# 9               Lewis Capaldi       182160     False
# 10                   Doja Cat       237894      True
# 11              Gabby Barrett       210772     False
# 12                Jack Harlow       139741      True
# 13                      Tones       209438     False
# 14        Megan Thee Stallion       155497      True
# 15             Arizona Zervas       163636      True
# 16              Justin Bieber       212868     False
# 17              Billie Eilish       245425     False
# 18                  Saint Jhn       176218      True
# 19               Harry Styles       173991     False
# 20              Lewis Capaldi       215106     False
# 21              Trevor Daniel       159381     False
# 22                 Dan + Shay       167693     False
# 23                    Cardi B       187546      True
# 24                    Mustard       180434      True
# 25                  Blackbear       188343      True
# 26                  Lil Mosey       162546      True
# 27                 The Weeknd       198266      True
# 28                     DaBaby       159714      True
# 29               Selena Gomez       206458     False
# 30                      Lizzo       159735     False
# 31                      Drake       247058      True
# 32                   Dua Lipa       221820     False
# 33              Morgan Wallen       205453     False
# 34                  Jawsh 685       171374      True
# 35                Chris Brown       260645      True
# 36             Camila Cabello       171375     False
# 37                        BTS       199053     False
# 38                Chris Brown       176960      True
# 39                Roddy Ricch       220486      True
# 40                      Drake       261492      True
# 41                   Lil Baby       183011      True
# 42                      Powfu       173333     False
# 43               Shawn Mendes       190960     False
# 44               Travis Scott       175720      True
# 45              Billie Eilish       194087     False
# 46                   24kGoldn       140525      True
# 47                  Lady Gaga       182200     False
# 48                  Pop Smoke       190476      True
# 49            Black Eyed Peas       214854      True
# 50                   Rod Wave       159669      True
# 51              Blake Shelton       194866     False
# 52                      Shaed       184060     False
# 53                 Juice Wrld       205484      True
# 54                      Lizzo       173325      True
# 55                    JP Saxe       208687     False
# 56                   Lil Baby       181929      True
# 57              Justin Bieber       210426     False
# 58               Old Dominion       186240     False
# 59               Jason Aldean       178146     False
# 60                   Surfaces       158638     False
# 61                     Eminem       210800      True
# 62                 Juice Wrld       189322      True
# 63             StaySolidRocky       147800      True
# 64               Maddie & Tae       188290     False
# 65                  DJ Khaled       200221      True
# 66               Mariah Carey       241562     False
# 67                  Lee Brice       188893     False
# 68                   Sam Hunt       204760     False
# 69                 Luke Bryan       193426     False
# 70                  Lil Nas X       114893     False
# 71                 Young Thug       193026      True
# 72               Carly Pearce       198688     False
# 73                   Lil Baby       197529      True
# 74                  YNW Melly       222997      True
# 75                   Lil Baby       252728      True
# 76             Jonas Brothers       183000     False
# 77                  Pop Smoke       201600     False
# 78                   Lil Baby       205760      True
# 79              Ariana Grande       228482     False
# 80                  Pop Smoke       213333      True
# 81                     Halsey       205473      True
# 82                  Pop Smoke       216386      True
# 83                      Benee       223488      True
# 84                 Luke Combs       225253     False
# 85   The Scotts (Travis Scott       165977      True
# 86                   Doja Cat       203093      True
# 87                 Kane Brown       191406     False
# 88                 Kane Brown       205405     False
# 89                   Rod Wave       235987      True
# 90            Miranda Lambert       209760     False
# 91                 Juice Wrld       194621      True
# 92                 Luke Combs       223760     False
# 93                 Jhené Aiko       181860      True
# 94                  Surf Mesa       176546     False
# 95              Morgan Wallen       216573     False
# 96                 Luke Combs       195093     False
# 97               Moneybagg Yo       155168      True
# 98                     H.E.R.       238321      True
# 192                   Huntrix       182016     False
# 193             Summer Walker       171000      True
# 194          Hudson Westbrook       203822     False
# 195                 Lil Tecca       136991      True
# 196               Don Toliver       187613      True
# 197                   Kehlani       238120     False
# 198             Morgan Wallen       188200     False
# 199                Netón Vega       186521     False

# %%
# create a column that identifies collaborations
allsongs["collab"] = allsongs["artist"].str.contains(
    r"featuring| and | & |,| x |:", # keywords for collabs
    case=False,
    regex=True
)

# %%
# calculate collaboration rate by year
collab_rate = allsongs.groupby("year")["collab"].mean().reset_index()
collab_rate["collab_percent"] = collab_rate["collab"] * 100
print(collab_rate)
# Out:
#    year  collab  collab_percent
# 0  2020    0.45            45.0
# 1  2025    0.29            29.0

# %%
pd.set_option("display.max_rows", None)
allsongs
# Out:
#      rank                               song  \
# 0       1                    Blinding Lights
# 1       2                            Circles
# 2       3                            The Box
# 3       4                    Don't Start Now
# 4       5                           Rockstar
# 5       6                          Adore You
# 6       7                       Life Is Good
# 7       8                           Memories
# 8       9                          The Bones
# 9      10                  Someone You Loved
# 10     11                             Say So
# 11     12                             I Hope
# 12     13                       Whats Poppin
# 13     14                       Dance Monkey
# 14     15                             Savage
# 15     16                            Roxanne
# 16     17                         Intentions
# 17     18                Everything I Wanted
# 18     19              Roses (Imanbek remix)
# 19     20                   Watermelon Sugar
# 20     21                      Before You Go
# 21     22                            Falling
# 22     23                       10,000 Hours
# 23     24                                WAP
# 24     25                            Ballin'
# 25     26                    Hot Girl Bummer
# 26     27                    Blueberry Faygo
# 27     28                          Heartless
# 28     29                                Bop
# 29     30                Lose You to Love Me
# 30     31                       Good as Hell
# 31     32                       Toosie Slide
# 32     33                     Break My Heart
# 33     34                        Chasin' You
# 34     35   Savage Love (Laxed – Siren Beat)
# 35     36                        No Guidance
# 36     37                           My Oh My
# 37     38                           Dynamite
# 38     39                           Go Crazy
# 39     40                       High Fashion
# 40     41                Laugh Now Cry Later
# 41     42                               Woah
# 42     43                          Death Bed
# 43     44                           Señorita
# 44     45                Highest in the Room
# 45     46                            Bad Guy
# 46     47                               Mood
# 47     48                         Rain on Me
# 48     49                      For the Night
# 49     50          Ritmo (Bad Boys for Life)
# 50     51                       Heart on Ice
# 51     52                     Nobody but You
# 52     53                         Trampoline
# 53     54                          Come & Go
# 54     55                        Truth Hurts
# 55     56            If the World Was Ending
# 56     57                            We Paid
# 57     58                              Yummy
# 58     59                       One Man Band
# 59     60                     Got What I Got
# 60     61                        Sunday Best
# 61     62                           Godzilla
# 62     63                             Bandit
# 63     64                         Party Girl
# 64     65            Die from a Broken Heart
# 65     66                            Popstar
# 66     67    All I Want for Christmas Is You
# 67     68                  One of Them Girls
# 68     69                     Hard to Forget
# 69     70                      One Margarita
# 70     71                             Panini
# 71     72                                Hot
# 72     73            I Hope You're Happy Now
# 73     74                Emotionally Scarred
# 74     75                           Suicidal
# 75     76                 The Bigger Picture
# 76     77                         Only Human
# 77     78                            The Woo
# 78     79                        Sum 2 Prove
# 79     80                       Stuck with U
# 80     81                        Mood Swings
# 81     82                  You Should Be Sad
# 82     83                               Dior
# 83     84                         Supalonely
# 84     85            Even Though I'm Leaving
# 85     86                         The Scotts
# 86     87                              Juicy
# 87     88                       Be Like That
# 88     89                           Homesick
# 89     90                        Rags2Riches
# 90     91                           Bluebird
# 91     92                       Wishing Well
# 92     93                         Does to Me
# 93     94                  Pussy Fairy (OTW)
# 94     95              ILY (I Love You Baby)
# 95     96              More Than My Hometown
# 96     97                      Lovin' on You
# 97     98                           Said Sum
# 98     99                              Slide
# 99    100                       Walk Em Down
# 100     1                   Die with a Smile
# 101     2                             Luther
# 102     3                 A Bar Song (Tipsy)
# 103     4                       Lose Control
# 104     5                 Birds of a Feather
# 105     6                   Beautiful Things
# 106     7                           Ordinary
# 107     8                    I Had Some Help
# 108     9                               APT.
# 109    10                     Pink Pony Club
# 110    11                      Love Somebody
# 111    12                           Espresso
# 112    13                    I'm the Problem
# 113    14                     That's So True
# 114    15                             TV Off
# 115    16                           Timeless
# 116    17                        Not Like Us
# 117    18                       Just in Case
# 118    19                              Taste
# 119    20                        Squabble Up
# 120    21                          30 for 30
# 121    22                               Mutt
# 122    23                          Good News
# 123    24                              Nokia
# 124    25                             Golden
# 125    26                         Wildflower
# 126    27                        What I Want
# 127    28                              Messy
# 128    29                         Stargazing
# 129    30                        Love Me Not
# 130    31                   Good Luck, Babe!
# 131    32                     No One Noticed
# 132    33                        All the Way
# 133    34                          Too Sweet
# 134    35                          Worst Way
# 135    36                        Sailor Song
# 136    37    Sorry I'm Here for Someone Else
# 137    38                           Manchild
# 138    39                            Anxiety
# 139    40                       I Got Better
# 140    41                             Sticky
# 141    42                          Undressed
# 142    43                        I Never Lie
# 143    44                    Back to Friends
# 144    45                           Bed Chem
# 145    46                         Sports Car
# 146    47                   Mystical Magical
# 147    48               Whatchu Kno About Me
# 148    49                             Indigo
# 149    50               Please Please Please
# 150    51                               DTMF
# 151    52                        Blue Strips
# 152    53                           Peekaboo
# 153    54                          Your Idol
# 154    55                          High Road
# 155    56                        Abracadabra
# 156    57                                Who
# 157    58                       Burning Blue
# 158    59    All I Want for Christmas Is You
# 159    60                            Daisies
# 160    61                           Soda Pop
# 161    62                           Like Him
# 162    63                          Residuals
# 163    64                              Smile
# 164    65                     Last Christmas
# 165    66                         Am I Okay?
# 166    67  Rockin' Around the Christmas Tree
# 167    68                      How It's Done
# 168    69                       Happen to Me
# 169    70                  Baile Inolvidable
# 170    71               Weren't for the Wind
# 171    72                I Ain't Comin' Back
# 172    73                         Cry for Me
# 173    74                         Bad Dreams
# 174    75                  Denial Is a River
# 175    76                                BMF
# 176    77                                Eoo
# 177    78                 I'm Gonna Love You
# 178    79                      I Am Not Okay
# 179    80                        Backup Plan
# 180    81                   Jingle Bell Rock
# 181    82                     Revolving Door
# 182    83                What It Sounds Like
# 183    84             Hard Fought Hallelujah
# 184    85                  Somebody Loves Me
# 185    86                               Liar
# 186    87                            Tu Boda
# 187    88      After All the Bars Are Closed
# 188    89                           Nuevayol
# 189    90                      20 Cigarettes
# 190    91                         Rather Lie
# 191    92                               Free
# 192    93                           Takedown
# 193    94                   Heart of a Woman
# 194    95                        House Again
# 154                  Koe Wetzel featuring Jessie Murph  2025
# 155                                          Lady Gaga  2025
# 156                                              Jimin  2025
# 157                               Mariah the Scientist  2025
# 158                                       Mariah Carey  2025
# 159                                      Justin Bieber  2025
# 160  Saja Boys: Andrew Choi, Neckwav, Danny Chung, ...  2025
# 161            Tyler, the Creator featuring Lola Young  2025
# 162                                        Chris Brown  2025
# 163                                      Morgan Wallen  2025
# 164                                              Wham!  2025
# 165                                      Megan Moroney  2025
# 166                                         Brenda Lee  2025
# 167             Huntrix: Ejae, Audrey Nuna and Rei Ami  2025
# 168                                  Russell Dickerson  2025
# 169                                          Bad Bunny  2025
# 170                                       Ella Langley  2025
# 171                Morgan Wallen featuring Post Malone  2025
# 172                                         The Weeknd  2025
# 173                                        Teddy Swims  2025
# 174                                            Doechii  2025
# 175                                                SZA  2025
# 176                                          Bad Bunny  2025
# 177                  Cody Johnson and Carrie Underwood  2025
# 178                                         Jelly Roll  2025
# 179                    Bailey Zimmerman and Luke Combs  2025
# 180                                        Bobby Helms  2025
# 181                                         Tate McRae  2025
# 182             Huntrix: Ejae, Audrey Nuna and Rei Ami  2025
# 183                        Brandon Lake and Jelly Roll  2025
# 184                            PartyNextDoor and Drake  2025
# 185                                         Jelly Roll  2025
# 186                     Óscar Maydon and Fuerza Regida  2025
# 187                                       Thomas Rhett  2025
# 188                                          Bad Bunny  2025
# 189                                      Morgan Wallen  2025
# 190                       Playboi Carti and the Weeknd  2025
# 191                               Ejae and Andrew Choi  2025
# 192             Huntrix: Ejae, Audrey Nuna and Rei Ami  2025
# 193                                      Summer Walker  2025
# 194                                   Hudson Westbrook  2025
# 195                                          Lil Tecca  2025
# 196                                        Don Toliver  2025
# 197                                            Kehlani  2025
# 198                                      Morgan Wallen  2025
# 199                                         Netón Vega  2025
#
#                  artist_clean  duration_ms  explicit  collab
# 0                  The Weeknd       200040     False   False
# 1                 Post Malone       215280     False   False
# 2                 Roddy Ricch       196652      True   False
# 3                    Dua Lipa       183290     False   False
# 4                      DaBaby       181733      True    True
# 5                Harry Styles       207139     False   False
# 6                      Future       237735      True    True
# 7                    Maroon 5       189486     False   False
# 8                Maren Morris       197298     False   False
# 9               Lewis Capaldi       182160     False   False
# 10                   Doja Cat       237894      True   False
# 11              Gabby Barrett       210772     False    True
# 12                Jack Harlow       139741      True    True
# 13                      Tones       209438     False    True
# 14        Megan Thee Stallion       155497      True    True
# 15             Arizona Zervas       163636      True   False
# 16              Justin Bieber       212868     False    True
# 17              Billie Eilish       245425     False   False
# 18                  Saint Jhn       176218      True   False
# 19               Harry Styles       173991     False   False
# 20              Lewis Capaldi       215106     False   False
# 21              Trevor Daniel       159381     False   False
# 22                 Dan + Shay       167693     False    True
# 23                    Cardi B       187546      True    True
# 24                    Mustard       180434      True    True
# 25                  Blackbear       188343      True   False
# 26                  Lil Mosey       162546      True   False
# 27                 The Weeknd       198266      True   False
# 28                     DaBaby       159714      True   False
# 29               Selena Gomez       206458     False   False
# 30                      Lizzo       159735     False   False
# 31                      Drake       247058      True   False
# 32                   Dua Lipa       221820     False   False
# 33              Morgan Wallen       205453     False   False
# 34                  Jawsh 685       171374      True    True
# 35                Chris Brown       260645      True    True
# 36             Camila Cabello       171375     False    True
# 37                        BTS       199053     False   False
# 38                Chris Brown       176960      True    True
# 39                Roddy Ricch       220486      True    True
# 40                      Drake       261492      True    True
# 41                   Lil Baby       183011      True   False
# 42                      Powfu       173333     False    True
# 43               Shawn Mendes       190960     False    True
# 44               Travis Scott       175720      True   False
# 45              Billie Eilish       194087     False   False
# 46                   24kGoldn       140525      True    True
# 47                  Lady Gaga       182200     False    True
# 48                  Pop Smoke       190476      True    True
# 49            Black Eyed Peas       214854      True    True
# 50                   Rod Wave       159669      True   False
# 51              Blake Shelton       194866     False    True
# 52                      Shaed       184060     False   False
# 53                 Juice Wrld       205484      True    True
# 54                      Lizzo       173325      True   False
# 55                    JP Saxe       208687     False    True
# 56                   Lil Baby       181929      True    True
# 57              Justin Bieber       210426     False   False
# 58               Old Dominion       186240     False   False
# 59               Jason Aldean       178146     False   False
# 60                   Surfaces       158638     False   False
# 61                     Eminem       210800      True    True
# 62                 Juice Wrld       189322      True    True
# 63             StaySolidRocky       147800      True   False
# 64               Maddie & Tae       188290     False    True
# 65                  DJ Khaled       200221      True    True
# 66               Mariah Carey       241562     False   False
# 67                  Lee Brice       188893     False   False
# 68                   Sam Hunt       204760     False   False
# 69                 Luke Bryan       193426     False   False
# 70                  Lil Nas X       114893     False   False
# 71                 Young Thug       193026      True    True
# 72               Carly Pearce       198688     False    True
# 73                   Lil Baby       197529      True   False
# 74                  YNW Melly       222997      True    True
# 75                   Lil Baby       252728      True   False
# 76             Jonas Brothers       183000     False   False
# 77                  Pop Smoke       201600     False    True
# 78                   Lil Baby       205760      True   False
# 79              Ariana Grande       228482     False    True
# 80                  Pop Smoke       213333      True    True
# 81                     Halsey       205473      True   False
# 82                  Pop Smoke       216386      True   False
# 83                      Benee       223488      True    True
# 84                 Luke Combs       225253     False   False
# 85   The Scotts (Travis Scott       165977      True    True
# 86                   Doja Cat       203093      True    True
# 87                 Kane Brown       191406     False    True
# 88                 Kane Brown       205405     False   False
# 89                   Rod Wave       235987      True    True
# 90            Miranda Lambert       209760     False   False
# 91                 Juice Wrld       194621      True   False
# 92                 Luke Combs       223760     False    True
# 93                 Jhené Aiko       181860      True   False
# 94                  Surf Mesa       176546     False    True
# 95              Morgan Wallen       216573     False   False
# 96                 Luke Combs       195093     False   False
# 97               Moneybagg Yo       155168      True   False
# 98                     H.E.R.       238321      True    True
# 99                 NLE Choppa       173288      True    True
# 100                 Lady Gaga       251667     False    True
# 101            Kendrick Lamar       177598     False    True
# 102                 Shaboozey       171291      True   False
# 103               Teddy Swims       210688     False   False
# 104             Billie Eilish       210373     False   False
# 105              Benson Boone       180304     False   False
# 106               Alex Warren       186964     False   False
# 107               Post Malone       178205      True    True
# 108                      Rosé       169917     False    True
# 109             Chappell Roan       258034     False   False
# 110             Morgan Wallen       204828     False   False
# 111         Sabrina Carpenter       175459     False   False
# 112             Morgan Wallen       177811     False   False
# 113             Gracie Abrams       166300      True   False
# 114            Kendrick Lamar       220690      True    True
# 115                The Weeknd       256000      True    True
# 116            Kendrick Lamar       274192      True   False
# 117             Morgan Wallen       166206     False   False
# 118         Sabrina Carpenter       157279     False   False
# 119            Kendrick Lamar       157992      True   False
# 120                       SZA       278277      True    True
# 121               Leon Thomas       193333      True   False
# 122                 Shaboozey       199209     False   False
# 123                     Drake       241023      True   False
# 124                   Huntrix       194607     False    True
# 125             Billie Eilish       261466     False   False
# 126             Morgan Wallen       184517     False    True
# 127                Lola Young       284068      True   False
# 128               Myles Smith       172533     False   False
# 129               Ravyn Lenae       213466     False   False
# 130             Chappell Roan       218423     False   False
# 131                The Marías       236906     False   False
# 132               BigXthaPlug       165000      True    True
# 133                    Hozier       251424     False   False
# 134               Riley Green       220558     False   False
# 135                Gigi Perez       211978     False   False
# 136              Benson Boone       156582     False   False
# 137         Sabrina Carpenter       213645      True   False
# 138                   Doechii       249302      True   False
# 139             Morgan Wallen       204963     False   False
# 140                     Tyler       255915      True    True
# 141                     Sombr       182088     False   False
# 142                  Zach Top       224906     False   False
# 143                     Sombr       199032     False   False
# 144         Sabrina Carpenter       171869     False   False
# 145                Tate McRae       165045     False   False
# 146              Benson Boone       165746     False   False
# 147                  GloRilla       149461      True    True
# 148                Sam Barber       286634     False    True
# 149         Sabrina Carpenter       186365      True   False
# 150                 Bad Bunny       237117      True   False
# 151              Jessie Murph       147209     False   False
# 152            Kendrick Lamar       155917      True    True
# 153                 Saja Boys       191537     False    True
# 154                Koe Wetzel       178416      True    True
# 155                 Lady Gaga       223398     False   False
# 156                     Jimin       170887     False   False
# 157      Mariah the Scientist       205724     False   False
# 158              Mariah Carey       241562     False   False
# 159             Justin Bieber       176453     False   False
# 160                 Saja Boys       150686     False    True
# 161                     Tyler       278014      True    True
# 162               Chris Brown       215178     False   False
# 163             Morgan Wallen       224127     False   False
# 164                     Wham!       262960     False   False
# 165             Megan Moroney       235002     False   False
# 166                Brenda Lee       126266     False   False
# 167                   Huntrix       176059     False    True
# 168         Russell Dickerson       183615     False   False
# 169                 Bad Bunny       367725      True   False
# 170              Ella Langley       193666     False   False
# 171             Morgan Wallen       175271     False    True
# 172                The Weeknd       224136      True   False
# 173               Teddy Swims       184577     False   False
# 174                   Doechii       159586      True   False
# 175                       SZA       180746      True   False
# 176                 Bad Bunny       204768      True   False
# 177              Cody Johnson       188106     False    True
# 178                Jelly Roll       198066     False   False
# 179          Bailey Zimmerman       181518     False    True
# 180               Bobby Helms       130973     False   False
# 181                Tate McRae       180032      True   False
# 182                   Huntrix       250268     False    True
# 183              Brandon Lake       316002     False    True
# 184             PartyNextDoor       182767      True    True
# 185                Jelly Roll       204933     False   False
# 186              Óscar Maydon       225880      True    True
# 187              Thomas Rhett       191839     False   False
# 188                 Bad Bunny       183685     False   False
# 189             Morgan Wallen       160901     False   False
# 190             Playboi Carti       209680      True    True
# 191                      Ejae       187963     False    True
# 192                   Huntrix       182016     False    True
# 193             Summer Walker       171000      True   False
# 194          Hudson Westbrook       203822     False   False
# 195                 Lil Tecca       136991      True   False
# 196               Don Toliver       187613      True   False
# 197                   Kehlani       238120     False   False
# 198             Morgan Wallen       188200     False   False
# 199                Netón Vega       186521     False   False

# %% [markdown]
# # CLEANING

# %%
# check if there are missing values in any columns
allsongs.isna().sum()
# Out:
# rank            0
# song            0
# artist          0
# year            0
# artist_clean    0
# duration_ms     0
# explicit        0
# collab          0
# dtype: int64

# %%
# convert song duration from milliseconds to minutes
allsongs["duration_min"] = allsongs["duration_ms"] / 60000

# %%
# remove duplicate rows if any exist
allsongs = allsongs.drop_duplicates()
allsongs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # SIMPLE SUMMARY STATISTICS

# %%
# summary statistics for song length by year
allsongs.groupby("year")[["duration_min"]].describe()
# Out:
#      duration_min                                                              \
#             count      mean       std       min       25%       50%       75%
# year
# 2020        100.0  3.256406  0.450070  1.914883  2.964158  3.245725  3.512983
# 2025        100.0  3.374606  0.685791  2.104433  2.931817  3.194800  3.735488
#
#
#           max
# year
# 2020  4.35820
# 2025  6.12875

# %%
# summary statistics for explicit songs
allsongs.groupby("year")["explicit"].describe()
# Out:
#      count unique    top freq
# year
# 2020   100      2  False   50
# 2025   100      2  False   67

# %%
# summary statistics for collaborations
allsongs.groupby("year")["collab"].describe()
# Out:
#      count unique    top freq
# year
# 2020   100      2  False   55
# 2025   100      2  False   71

# %%
# average song length for collabs vs solo songs
allsongs.groupby("collab")["duration_min"].mean()
# Out:
# collab
# False    3.290973
# True     3.357278
# Name: duration_min, dtype: float64

# %%
# calculate several key statistics grouped by year
allsongs.groupby("year").agg(
    avg_length=("duration_min","mean"),
    median_length=("duration_min","median"),
    shortest_song=("duration_min","min"),
    longest_song=("duration_min","max"),
    explicit_rate=("explicit","mean"),
    collab_rate=("collab","mean")
)
# Out:
#       avg_length  median_length  shortest_song  longest_song  explicit_rate  \
# year
# 2020    3.256406       3.245725       1.914883       4.35820           0.50
# 2025    3.374606       3.194800       2.104433       6.12875           0.33
#
#       collab_rate
# year
# 2020         0.45
# 2025         0.29

# %%
# find the most common artists appearing in the dataset
top_artists = allsongs["artist_clean"].value_counts().head(10)

sns.barplot(x=top_artists.values, y=top_artists.index)
plt.title("Most Frequent Artists in Dataset")
plt.xlabel("Number of Songs")
plt.ylabel("Artist")
plt.show()

# %%
# compute correlation between song features
corr = allsongs[["rank","duration_min","explicit","collab"]].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Between Song Features")
plt.show()

# %% [markdown]
# # 1st QUESTION: ARE SONGS SHORTER

# %%
# calculate average song length by year
allsongs.groupby("year")["duration_min"].mean()
# Out:
# year
# 2020    3.256406
# 2025    3.374606
# Name: duration_min, dtype: float64

# %%
# barplot of the average song length comparison
sns.barplot(data=allsongs, x="year", y="duration_min")
plt.title("Average Song Length by Year")
plt.ylabel("Minutes")
plt.show()

# %%
#convert to minutes
allsongs["duration_min"] = allsongs["duration_ms"] / 60000

# kde plot showing distribution of song lengths
sns.kdeplot(data=allsongs, x="duration_min", hue="year", fill=True)
plt.xlabel("Song Length (minutes)")
plt.title("Distribution of Song Lengths (2020 vs 2025)")
plt.show()

# %% [markdown]
# for above, The KDE distribution shows that most songs in both 2020 and 2025 are approximately three minutes long. However, the 2025 distribution is slightly wider and includes more longer songs, suggesting a small increase in song length variability compared to 2020.

# %%
# box plot to compare song length distributions
sns.boxplot(data=allsongs, x="year", y="duration_min")
plt.xlabel("Year")
plt.ylabel("Song Length (minutes)")
plt.title("Song Length Comparison: 2020 vs 2025")
plt.show()

# %%
# scatter plot to see if billboard rank is related to song length
sns.scatterplot(data=allsongs, x="rank", y="duration_min", hue="year")
plt.title("Song Rank vs Duration")
plt.xlabel("Billboard Rank")
plt.ylabel("Song Length (minutes)")
plt.show()

# %% [markdown]
# for above, we see that Song length does not appear to strongly influence Billboard ranking.

# %% [markdown]
# # 2nd QUESTION: ARE SONGS MORE EXPICIT?

# %%
# calculate percent of explicit songs by year
explicit_rate = allsongs.groupby("year")["explicit"].mean().reset_index()
explicit_rate["percent"] = explicit_rate["explicit"] * 100

# visualize explicit song percentages
sns.barplot(data=explicit_rate, x="year", y="percent", color="#ffb3b3")
plt.title("Explicit Songs in Billboard Hot 100")
plt.ylabel("Percent Explicit")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # 3rd QUESTION: ARE SONGS MORE COLLABORATIVE?

# %%
# calculate collaboration rate by year
collab_rate = allsongs.groupby("year")["collab"].mean().reset_index()
collab_rate["collab_percent"] = collab_rate["collab"] * 100

# visualize collaboration rate
sns.barplot(data=collab_rate, x="year", y="collab_percent")
plt.ylabel("Percent of Collaborative Songs")
plt.xlabel("Year")
plt.title("Collaborations in Billboard Top 100")
plt.show()

# %%
# create readable labels for solo vs collaborative songs
allsongs["collab_label"] = allsongs["collab"].map({
    False: "Solo",
    True: "Collaboration"
})

allsongs.head(10)
# Out:
#    rank               song                        artist  year   artist_clean  \
# 0     1    Blinding Lights                    The Weeknd  2020     The Weeknd
# 1     2            Circles                   Post Malone  2020    Post Malone
# 2     3            The Box                   Roddy Ricch  2020    Roddy Ricch
# 3     4    Don't Start Now                      Dua Lipa  2020       Dua Lipa
# 4     5           Rockstar  DaBaby featuring Roddy Ricch  2020         DaBaby
# 5     6          Adore You                  Harry Styles  2020   Harry Styles
# 6     7       Life Is Good        Future featuring Drake  2020         Future
# 7     8           Memories                      Maroon 5  2020       Maroon 5
# 8     9          The Bones                  Maren Morris  2020   Maren Morris
# 9    10  Someone You Loved                 Lewis Capaldi  2020  Lewis Capaldi
#
#    duration_ms  explicit  collab  duration_min   collab_label
# 0       200040     False   False      3.334000           Solo
# 1       215280     False   False      3.588000           Solo
# 2       196652      True   False      3.277533           Solo
# 3       183290     False   False      3.054833           Solo
# 4       181733      True    True      3.028883  Collaboration
# 5       207139     False   False      3.452317           Solo
# 6       237735      True    True      3.962250  Collaboration
# 7       189486     False   False      3.158100           Solo
# 8       197298     False   False      3.288300           Solo
# 9       182160     False   False      3.036000           Solo

# %%
# count plot showing solo vs collaboration counts by year
sns.countplot(
    data=allsongs,
    x="year",
    hue="collab_label",
    palette=["#a8d8ff", "#ffb3b3"]
)

plt.xlabel("Year")
plt.ylabel("Number of Songs")
plt.title("Solo vs Collaborative Songs")

plt.legend(title="Song Type")

plt.show()
